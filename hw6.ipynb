# %%
import numpy as np
import matplotlib.pyplot as plt
import yx_ODE as p1
import Unstable_ODE as p2

# %% [markdown]
# # Problem 1: Solve an ODE with Euler's Method
# The reason the problem is hard to solve numerically with step size = 1 is because that step size is far too large, and Euler's method is prone to over-correction.

# %%
p1.run()

# %% [markdown]
# # Problem 2: Experience instability of an ODE
# The solution of u' = a x u is simple, but using Euler's method makes the solution oscillate to converge on the answer. Graph #3 shows this the best, when dt < -1/a, the method diverges greatly because it is unstable.

# %%
p2.run(-1, 1.1,1)

# %%
p2.run(-1, 1.5, 1)

# %%
p2.run(-1, 1.9, 1)

# %%
p2.run(2, 1, 1)
